# %% [markdown]
# <a href="https://colab.research.google.com/github/BlitzKriegM/C-digos-Proyecto/blob/main/Modelo_cargado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain huggingface_hub  sentence_transformers accelerate bitsandbytes python_dotenv
# !pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.6/315.6 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 37.5 MB/s eta 0:00:00

# %%
from transformers import AutoTokenizer, pipeline, AutoModelForSeq2SeqLM

# %%
model_id = 'DannySte/espacios'

tokenizer = AutoTokenizer.from_pretrained(model_id)
model =  AutoTokenizer.from_pretrained(model_id,
                                              load_in_4bit=True,
                                              device_map='auto')
# Out:
# tokenizer_config.json:   0%|          | 0.00/40.0k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %%
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM

model_id = 'DannySte/espacios'
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

model_generator = pipeline(
    "text2text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=2076,

)
# Out:
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/116k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/573M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2b9bd6a08073> in <cell line: 5>()
#       3 model_id = 'DannySte/espacios'
#       4 tokenizer = AutoTokenizer.from_pretrained(model_id)
# ----> 5 model = AutoModelForCausalLM.from_pretrained(model_id)
#       6
# ...

# %%
# @title Default title text
model_generator(" ¿Cuál es el protocolo requerido para que una entidad aeronáutica notifique un cambio en la ubicación de sus bases, oficinas o zonas de operación?")
# Out:
# [{'generated_text': ' ¿Cuál es el protocolo requerido para que una entidad aeronáutica notifique un cambio en la ubicación de sus bases, oficinas o zonas de operación?\n# model\n{\n    "pregunta": "\\u00bfCu\\u00e1l es el protocolo requerido para que una entidad aeron\\u00e1utica notifique un cambio en la ubicaci\\u00f3n de sus bases, oficinas o zonas de operaci\\u00f3n?",\n    "respuesta": "Deben notificar por escrito, de manera detallada, el cambio a la Direcci\\u00f3n de Est\\u00e1ndares de Vuelo o a la Secci\\u00f3n de Servicios a la Navegaci\\u00f3n A\\u00e9rea.",\n    "pagina": "33",\n    "rac": "Rac 3"\n}'}]
